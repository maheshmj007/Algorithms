# %% [markdown]
# # Dijkstra’s shortest path algorith
# * Name: Mahesh M J
# * Reg No. : 19-26-07

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import sys
# enter adjacency matrix as a array graph
graph = np.array([[0, 4, 0, 0, 0, 0, 0, 8, 0], 
        [4, 0, 8, 0, 0, 0, 0, 11, 0], 
        [0, 8, 0, 7, 0, 4, 0, 0, 2], 
        [0, 0, 7, 0, 9, 14, 0, 0, 0], 
        [0, 0, 0, 9, 0, 10, 0, 0, 0], 
        [0, 0, 4, 14, 10, 0, 2, 0, 0], 
        [0, 0, 0, 0, 0, 2, 0, 1, 6], 
        [8, 11, 0, 0, 0, 0, 1, 0, 7], 
        [0, 0, 2, 0, 0, 0, 6, 7, 0] 
        ])

# %%
spt_set = set(np.linspace(0,8,num=9,dtype='int'))
dist = dict(zip(spt_set,[sys.maxsize]*9))

def mindist(dist,spt_set):
    min_i = sys.maxsize
    index = -1
    for i in spt_set:
        if dist[i] < min_i:
            index = i
            min_i = dist[i]
    return index

# %%
src = 0
dest = 6
dist[src] = 0

while len(spt_set) > 0:
    spt_set.remove(src)
    print('source',src)
    edge = np.nonzero(graph[src])
    for e in edge[0]:
        if e in spt_set and dist[e] > dist[src] + graph[src][e]:
            dist[e] = dist[src] + graph[src][e]
    print(dist)
    src = mindist(dist,spt_set)
print('Dijkstra’s shortest distance :',dist[dest])
# Out:
# source 0
# {0: 0, 1: 4, 2: 9223372036854775807, 3: 9223372036854775807, 4: 9223372036854775807, 5: 9223372036854775807, 6: 9223372036854775807, 7: 8, 8: 9223372036854775807}
# source 1
# {0: 0, 1: 4, 2: 12, 3: 9223372036854775807, 4: 9223372036854775807, 5: 9223372036854775807, 6: 9223372036854775807, 7: 8, 8: 9223372036854775807}
# source 7
# {0: 0, 1: 4, 2: 12, 3: 9223372036854775807, 4: 9223372036854775807, 5: 9223372036854775807, 6: 9, 7: 8, 8: 15}
# source 6
# {0: 0, 1: 4, 2: 12, 3: 9223372036854775807, 4: 9223372036854775807, 5: 11, 6: 9, 7: 8, 8: 15}
# source 5
# {0: 0, 1: 4, 2: 12, 3: 25, 4: 21, 5: 11, 6: 9, 7: 8, 8: 15}
# source 2
# {0: 0, 1: 4, 2: 12, 3: 19, 4: 21, 5: 11, 6: 9, 7: 8, 8: 14}
# source 8
# {0: 0, 1: 4, 2: 12, 3: 19, 4: 21, 5: 11, 6: 9, 7: 8, 8: 14}
# source 3
# {0: 0, 1: 4, 2: 12, 3: 19, 4: 21, 5: 11, 6: 9, 7: 8, 8: 14}
# source 4
# {0: 0, 1: 4, 2: 12, 3: 19, 4: 21, 5: 11, 6: 9, 7: 8, 8: 14}
# Dijkstra’s shortest distance : 9

# %% [markdown]
# ![image.png](attachment:image.png)
